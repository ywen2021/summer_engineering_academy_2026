# %% [markdown]
# In this notebook, we will learn what Large Language Models (LLMs) are and how they work.

# %% [markdown]
# ## 1. What is a Large Language Model?
#
# A **Large Language Model**, or **LLM**, is an AI model that learns patterns from a very large amount of text.
#
# It can help with tasks such as:
#
# - finishing a sentence
# - answering questions
# - summarizing text
# - translating languages
# - writing drafts
# - explaining code
# - brainstorming ideas
#
# An LLM does **not** truly “understand” like a human. It predicts likely words based on patterns it learned during training.

# %% [markdown]
# ## 2. Setup
#
# We will use the Hugging Face `transformers` library.
#
# Run the cell below first. In Google Colab, this may take a minute.

# %%
# !pip -q install transformers accelerate torch

# %% [markdown]
# ## 3. Import the Tools
#
# The main tool we will use is called `pipeline`.
#
# A **pipeline** is a simple way to use an AI model without writing a lot of complicated code.

# %%
from transformers import pipeline, set_seed
import textwrap

def print_wrapped(text, width=90):
    # Print long text in a more readable way.
    print(textwrap.fill(text, width=width))

# %% [markdown]
# ## 4. First Example: Sentiment Analysis
#
# **Sentiment analysis** means deciding whether a sentence sounds positive or negative.
#
# For example:
#
# - “I love this class!” → positive
# - “This was confusing and frustrating.” → negative
#
# Let’s try it.

# %%
sentiment_model = pipeline("sentiment-analysis")

sentences = [
    "I am excited to learn about artificial intelligence!",
    "This homework is difficult and confusing.",
    "The movie was okay, but the ending was amazing."
]

results = sentiment_model(sentences)

for sentence, result in zip(sentences, results):
    print("Sentence:", sentence)
    print("Prediction:", result)
    print()
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Sentence: I am excited to learn about artificial intelligence!
# Prediction: {'label': 'POSITIVE', 'score': 0.9997140765190125}
#
# Sentence: This homework is difficult and confusing.
# Prediction: {'label': 'NEGATIVE', 'score': 0.9983299374580383}
#
# Sentence: The movie was okay, but the ending was amazing.
# Prediction: {'label': 'POSITIVE', 'score': 0.9998594522476196}

# %% [markdown]
# ### Activity 1: Try Your Own Sentences
#
# Change the sentences below and run the cell again.
#
# Try examples that are:
#
# 1. clearly positive
# 2. clearly negative
# 3. mixed or unclear

# %%
my_sentences = [
    "Type your first sentence here.",
    "Type your second sentence here.",
    "Type your third sentence here."
]

sentiment_model(my_sentences)

# %% [markdown]
# ## 5. Text Generation with a Small LLM
#
# Now we will use a small language model called **DistilGPT2**.
#
# It is much smaller than tools like ChatGPT, so the output may be less impressive. But it is useful for learning because it can run in a notebook.
#
# The model starts with a prompt and tries to continue it.

# %%
generator = pipeline("text-generation", model="distilbert/distilgpt2")
set_seed(42)

prompt = "In the future, robots will help humans by"

output = generator(
    prompt,
    max_new_tokens=40,
    num_return_sequences=1,
    do_sample=True,
    temperature=0.8,
    pad_token_id=generator.tokenizer.eos_token_id
)

print_wrapped(output[0]["generated_text"])
# Out:
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'pad_token_id', 'do_sample', 'temperature', 'max_new_tokens', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# In the future, robots will help humans by taking care of a specific person in their own
# right. And that’s exactly what we‖ve designed here.     The concept of a robot will soon
# become more widespread

# %% [markdown]
# ### What Just Happened?
#
# The model was given this beginning:
#
# > In the future, robots will help humans by
#
# Then it predicted words that could come next.
#
# Important idea:
#
# > The model is not copying one correct answer. It is generating a possible continuation.

# %% [markdown]
# ## 6. Prompt Experiment
#
# A **prompt** is the instruction or input we give to an AI model.
#
# Small changes in prompts can lead to different outputs.
#
# Run the cell below, then change the prompt and compare the result.

# %%
prompt = "Write a short story about a student who builds an AI robot"

output = generator(
    prompt,
    max_new_tokens=70,
    num_return_sequences=1,
    do_sample=True,
    temperature=0.9,
    pad_token_id=generator.tokenizer.eos_token_id
)

print_wrapped(output[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=70) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Write a short story about a student who builds an AI robot.     Asking for the source code
# can be tricky. When it is a good idea, a developer should ask to get the code for
# production, which can lead to a lengthy discussion. In addition, this might lead to
# misunderstandings. Sometimes, an important project can get bogged down in the process of
# development, and

# %% [markdown]
# ## 7. What Are Tokens?
#
# LLMs do not read text exactly the way humans do. They break text into smaller pieces called **tokens**.
#
# A token can be:
#
# - a word
# - part of a word
# - punctuation
# - a space-like symbol
#
# Let’s see how a tokenizer breaks a sentence into pieces.

# %%
tokenizer = generator.tokenizer

sentence = "Artificial intelligence can help students learn in creative ways."

tokens = tokenizer.tokenize(sentence)
token_ids = tokenizer.convert_tokens_to_ids(tokens)

print("Original sentence:")
print(sentence)

print("\nTokens:")
print(tokens)

print("\nToken IDs:")
print(token_ids)

print("\nNumber of tokens:", len(tokens))
# Out:
# Original sentence:
# Artificial intelligence can help students learn in creative ways.
#
# Tokens:
# ['Art', 'ificial', 'Ġintelligence', 'Ġcan', 'Ġhelp', 'Ġstudents', 'Ġlearn', 'Ġin', 'Ġcreative', 'Ġways', '.']
#
# Token IDs:
# [8001, 9542, 4430, 460, 1037, 2444, 2193, 287, 7325, 2842, 13]
#
# Number of tokens: 11

# %% [markdown]
# ## 8. Mini Chatbot Function
#
# The model we are using is not a real chat assistant, but we can still build a simple text-generation demo.
#
# This function takes your message and asks the model to continue it.

# %%
def simple_llm_response(user_message, max_new_tokens=60, temperature=0.8):
    prompt = "Student: " + user_message + "\nAI:"
    output = generator(
        prompt,
        max_new_tokens=max_new_tokens,
        num_return_sequences=1,
        do_sample=True,
        temperature=temperature,
        pad_token_id=generator.tokenizer.eos_token_id
    )
    response = output[0]["generated_text"]
    return response

message = "Can you give me one idea for using AI to help the environment?"
print_wrapped(simple_llm_response(message))
# Out:
# [transformers] Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Student: Can you give me one idea for using AI to help the environment? AI: We are looking
# for a simple way to get this kind of AI to work out. I am a robot that can act as an AI.
# The human being is the AI. The human being is the AI. We look at AI and we try to make
# sure that we are using it in our own
